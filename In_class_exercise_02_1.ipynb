# %% [markdown]
# <a href="https://colab.research.google.com/github/Supraja1419/Supraja_INFO5731_Spring2022/blob/main/In_class_exercise_02_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:
My Interesting research  is looking for quotes from famous people. Having a new quote every week for the next whole year.The task is  to present at least fifty-two quotes and their respective authors.

Detail steps: 1. We will start by importing the libraries needed for BeautifulSoup.
              2.Next, I have to actually access the website for BeautifulSoup to parse 
              3.Now, I need to find the exact thing that am looking for in the parsed HTML document.
              4.Save the required and usefull data. 




'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):
#importing the useful libraries
from bs4 import BeautifulSoup as bs 
import pandas as pd
pd.set_option('display.max_colwidth', 500) #Defining  the width of the column
import time
import requests
import random
page = requests.get("http://quotes.toscrape.com/")
page
# <Response [200]> # Here I am looking for Response [200] meaning that we have successfully reached the website.
soup = bs(page.content)
soup #Running this code will return what looks like a printed text document in HTML code.
soup.find_all(class_='text') #able to successfully locate and retrieve the code and text containing the quotes needed.
authors = [i.text for i in soup.find_all(class_='author')] 
urls=[f"http://quotes.toscrape.com/page/{i}/" for i in range(1,10001)]
urls
# Out:
# ['http://quotes.toscrape.com/page/1/',
#  'http://quotes.toscrape.com/page/2/',
#  'http://quotes.toscrape.com/page/3/',
#  'http://quotes.toscrape.com/page/4/',
#  'http://quotes.toscrape.com/page/5/',
#  'http://quotes.toscrape.com/page/6/',
#  'http://quotes.toscrape.com/page/7/',
#  'http://quotes.toscrape.com/page/8/',
#  'http://quotes.toscrape.com/page/9/',
#  'http://quotes.toscrape.com/page/10/',
#  'http://quotes.toscrape.com/page/11/',
#  'http://quotes.toscrape.com/page/12/',
#  'http://quotes.toscrape.com/page/13/',
#  'http://quotes.toscrape.com/page/14/',
#  'http://quotes.toscrape.com/page/15/',
#  'http://quotes.toscrape.com/page/16/',
#  'http://quotes.toscrape.com/page/17/',
#  'http://quotes.toscrape.com/page/18/',
#  'http://quotes.toscrape.com/page/19/',
#  'http://quotes.toscrape.com/page/20/',
#  'http://quotes.toscrape.com/page/21/',
#  'http://quotes.toscrape.com/page/22/',
#  'http://quotes.toscrape.com/page/23/',
#  'http://quotes.toscrape.com/page/24/',
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
#importing the useful libraries
from bs4 import BeautifulSoup as bs 
import re 
import pandas as pd
pd.set_option('display.max_colwidth', 500) #Defining  the width of the column
import time
import requests
import random

page = requests.get("https://www.semanticscholar.org/paper/Information-Retrieval-Dekhtyar/72c58a58ba1684dc8337c8e64e0b5dacfc94499e")
page
# Here I am looking for Response [200] meaning that we have successfully reached the website
soup = bs(page.content)

soup #Running this code will return what looks like a printed text document in HTML code.
soup.find_all(class_='Information Retrieval')
print("Title of the website is : ")
from urllib.request import urlopen
import re
url = "https://www.semanticscholar.org/paper/Information-Retrieval-Dekhtyar/72c58a58ba1684dc8337c8e64e0b5dacfc94499e"
page = urlopen(url)
html = page.read().decode("utf-8")

pattern = "<title.*?>.*?</title.*?>"
match_results = re.search(pattern, html, re.IGNORECASE)
title = match_results.group()
title = re.sub("<.*?>", "", title) # Remove HTML tags
print(title)
#soup.find('h1').Text
inner_text = [item.text for item in soup.find_all('author')]
print(inner_text)
print ("journal is:")
for journal in soup.find_all('journal'):
    print(journal.get_journal())
print("Year of the website is : ")
for Year in soup.find_all("Year"):
    print(year.get_year())
print("Author of the website is : ")
for author in soup.find_all("author"):
  print(author.get_author())
# Out:
# Title of the website is :
# [PDF] Information Retrieval | Semantic Scholar
# []
# journal is:
# Year of the website is :
# Author of the website is :

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):
# importing libraries and packages
import snscrape.modules.twitter as sntwitter
import pandas

# Creating list to append tweet data 
tweets_list1 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:jack').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list1.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
# Creating a dataframe from the tweets list above 
tweets_df1 = pd.DataFrame(tweets_list1, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-ee535c5ef690> in <module>()
#       1 # You code here (Please add comments in the code):
#       2 # importing libraries and packages
# ----> 3 import snscrape.modules.twitter as sntwitter
#       4 import pandas
#       5
#
# ModuleNotFoundError: No module named 'snscrape'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
